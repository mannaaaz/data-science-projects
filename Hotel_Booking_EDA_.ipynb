# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Data Exploration**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/hotel_bookings.csv")
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#Visulizating individual columns

plt.figure(figsize=(12, 12), dpi=80)

plt.subplot(4, 2, 1)
plt.title('Hotel')
sns.countplot(x='hotel', data=df, palette='muted')

plt.subplot(4, 2, 2)
plt.title('Meals')
sns.countplot(x='meal', data=df, palette='colorblind')

plt.subplot(4, 2, 3)
plt.title('Assigned Room Type')
sns.countplot(x='assigned_room_type', data=df, palette='rocket')

plt.subplot(4, 2, 4)
plt.title('Total of Special Requests')
sns.countplot(x='total_of_special_requests', data=df, palette='coolwarm')

plt.subplot(4, 2, 5)
plt.title('Reservation Status')
sns.countplot(x='reservation_status', data=df, palette='hot')

plt.subplot(4, 2, 6)
plt.title('Deposit Type')
sns.countplot(x='deposit_type', data=df, palette='bright')

plt.subplot(4, 2, 7)
plt.title('Distribution of Lead Time')
sns.histplot(df['lead_time'], bins=30, color='skyblue', edgecolor='black', kde=True)
plt.xlabel('Lead Time')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Data Cleaning**

# %%
#sns.heatmap(df.isnull())
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
print(df.isnull().sum())
# columns that has missing values:
# country: 488 - agent: 16340 - company: 112593
# country of origin - agent: ID of the travel agency that made the booking - company: ID of the company/entity that made the booking or responsible for paying the booking.
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# % of mising values
missing_percentage = (df.isnull().sum() / len(df)) * 100
print(missing_percentage)
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %%
#drop the company's column
df.drop('company', axis=1, inplace=True)

# %%
plt.hist(df['agent'].dropna(), bins=30, color='blue', edgecolor='black')
plt.title('Distribution of Agent Column')
plt.xlabel('Agent')
plt.ylabel('Frequency')
plt.show()
# a bit right skewed with outliers!

# %%
from scipy.stats import skew, kurtosis

agent_column = df['agent'].dropna()

print(f"Skewness: {skew(agent_column)}")
print(f"Kurtosis: {kurtosis(agent_column)}")
# Out:
# Skewness: 1.0893697789030417
# Kurtosis: -0.0072374401868660065

# %%
#use the median to impute the missing values in agent column
df['agent'].fillna(df['agent'].median(), inplace=True)

# %%
plt.hist(df['country'].dropna(), bins=30, color='red', edgecolor='black')
plt.title('Distribution of Country Column')
plt.xlabel('Country')
plt.ylabel('Frequency')
plt.show()

# %%
print(df['country'].unique())
print(df['country'].mode())
#mode is PRT
# Out:
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
#  'NPL' 'BHS' 'MAC' 'TGO' 'TWN' 'DJI' 'STP' 'KNA' 'ETH' 'IRQ' 'HND' 'RWA'
#  'KHM' 'MCO' 'BGD' 'IMN' 'TJK' 'NIC' 'BEN' 'VGB' 'TZA' 'GAB' 'GHA' 'TMP'
#  'GLP' 'KEN' 'LIE' 'GNB' 'MNE' 'UMI' 'MYT' 'FRO' 'MMR' 'PAN' 'BFA' 'LBY'
# ...

# %%
df['country'].fillna(df['country'].mode()[0], inplace=True)
#Fill missing values with the mode => country is a categorical value

# %%
df.drop('children', axis=1, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# ### **EDA to decide which features are important**

# %%
#explore monthly treands

# Convert 'arrival_date_month' to a categorical data type for proper ordering
months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['arrival_date_month'] = pd.Categorical(df['arrival_date_month'], categories=months_order, ordered=True)

# Create a bar plot of bookings per month
plt.figure(figsize=(12, 6))
sns.countplot(x='arrival_date_month', data=df, hue='is_canceled', palette='viridis')
plt.title('Bookings per Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
# Create box plots for categorical features
categorical_features = ['market_segment', 'distribution_channel', 'reserved_room_type', 'deposit_type', 'customer_type']
for feature in categorical_features:
    plt.figure(figsize=(12, 6))
    sns.countplot(x=feature, data=df, hue='is_canceled', palette='viridis')
    plt.title(f'{feature} vs. Booking Cancellation')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.show()

# %%
#Statistical tests: help  assess the significance of relationships between categorical features and the target variable.

import scipy.stats as stats

# List of categorical features
categorical_features = ['market_segment', 'distribution_channel', 'customer_type', 'deposit_type', 'reserved_room_type']

for feature in categorical_features:
    # Create a contingency table
    contingency_table = pd.crosstab(df[feature], df['is_canceled'])

    # Perform the chi-squared test
    chi2, p, _, _ = stats.chi2_contingency(contingency_table)

    # Print the results
    print(f'Chi-squared test for {feature}:')
    print(f'Chi2 Statistic: {chi2:.4f}')
    print(f'p-value:{p:.4f}')
    print('\n')

#based on the chi-squared tests, all the tested categorical features appear to be important in relation to predicting whether a booking is canceled or not.
# Out:
# Chi-squared test for market_segment:
# Chi2 Statistic: 8497.2241
# p-value:0.0000
#
#
# Chi-squared test for distribution_channel:
# Chi2 Statistic: 3745.7941
# p-value:0.0000
#
#
# Chi-squared test for customer_type:
# Chi2 Statistic: 2222.5042
# p-value:0.0000
#
#
# Chi-squared test for deposit_type:
# Chi2 Statistic: 27677.3292
# p-value:0.0000
#
#
# Chi-squared test for reserved_room_type:
# Chi2 Statistic: 647.8351
# p-value:0.0000

# %% [markdown]
# ### **Outlier detection**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

categorical_features = ['arrival_date_month', 'market_segment', 'distribution_channel', 'customer_type', 'deposit_type', 'reserved_room_type']

for feature in categorical_features:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=feature, data=df, palette='viridis')
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.show()
